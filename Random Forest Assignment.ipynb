# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_glass = pd.read_excel(r"C:\Users\VICTUS\Downloads\Random Forest\Random Forest\glass.xlsx",'glass')

# %%
df_glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df = pd.read_excel(r"C:\Users\VICTUS\Downloads\Random Forest\Random Forest\glass.xlsx")

# %%
df
# Out:
#    Prepare a model for glass classification using Random Forest
# 0                                   Data Description:
# 1                               RI : refractive index
# 2   Na: Sodium (unit measurement: weight percent i...
# 3                                       Mg: Magnesium
# 4                                        AI: Aluminum
# 5                                         Si: Silicon
# 6                                         K:Potassium
# 7                                         Ca: Calcium
# 8                                          Ba: Barium
# 9                                            Fe: Iron
# 10                                                NaN
# 11             Type: Type of glass: (class attribute)
# 12              1 -- building_windows_float_processed
# 13           2 --building_windows_non_float_processed
# 14                3 --vehicle_windows_float_processed
# 15   4 --vehicle_windows_non_float_processed (none...
# ...

# %%
df_glass.isna().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df_glass.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
df_glass.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df_glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Histogram

# %%
sns.set_theme(style='darkgrid',palette='viridis')
plt.figure(figsize=(32,18))
plt.subplot(3,3,1)
sns.histplot(x=df_glass.RI,kde=True)
plt.subplot(3,3,2)
sns.histplot(x=df_glass.Na,kde=True)
plt.subplot(3,3,3)
sns.histplot(x=df_glass.Mg,kde=True)
plt.subplot(3,3,4)
sns.histplot(x=df_glass.Al,kde=True)
plt.subplot(3,3,5)
sns.histplot(x=df_glass.Si,kde=True)
plt.subplot(3,3,6)
sns.histplot(x=df_glass.K,kde=True)
plt.subplot(3,3,7)
sns.histplot(x=df_glass.Ca,kde=True)
plt.subplot(3,3,8)
sns.histplot(x=df_glass.Ba,kde=True)
plt.subplot(3,3,9)
sns.histplot(x=df_glass.Fe,kde=True)
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(32,18))
plt.subplot(3,3,1)
plt.boxplot(df_glass.RI,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of RI')
plt.subplot(3,3,2)
plt.boxplot(df_glass.Na,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of Na')
plt.subplot(3,3,3)
plt.boxplot(df_glass.Mg,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of Mg')
plt.subplot(3,3,4)
plt.boxplot(df_glass.Al,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of Al')
plt.subplot(3,3,5)
plt.boxplot(df_glass.Si,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of si')
plt.subplot(3,3,6)
plt.boxplot(df_glass.K,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of K')
plt.subplot(3,3,7)
plt.boxplot(df_glass.Ca,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of Ca')
plt.subplot(3,3,8)
plt.boxplot(df_glass.Ba,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of Ba')
plt.subplot(3,3,9)
plt.boxplot(df_glass.Fe,notch=True,medianprops={'color':'r'})
plt.title('Boxplot of Fe')
plt.show()

# %% [markdown]
# # Handling Outliers

# %%
def Outliers(data,columns):
    for col in columns:
        q1 = df_glass[col].quantile(0.25)
        q3 = df_glass[col].quantile(0.75)
        IQR = q3 - q1
        Low_ext = q1 - (1.5*IQR)
        Upp_ext = q3 + (1.5*IQR)
        df_glass[col] = np.where(df_glass[col]>Upp_ext,Upp_ext,np.where(df_glass[col]<Low_ext,Low_ext,df_glass[col]))

# %%
Outliers(df_glass,df_glass.iloc[:,0:2])

# %%
Outliers(df_glass,df_glass.iloc[:,3:7])

# %%
Outliers(df_glass,df_glass.iloc[:,8:9])

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df_glass)
plt.show()

# %% [markdown]
# # Coorelation Metrics

# %%
df_glass.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.064047 -0.032721 -0.470391 -0.532124 -0.344942  0.760449
# Na   -0.064047  1.000000 -0.295178  0.208865 -0.164674 -0.493401 -0.102396
# Mg   -0.032721 -0.295178  1.000000 -0.474507 -0.210539  0.326625 -0.371040
# Al   -0.470391  0.208865 -0.474507  1.000000  0.142701  0.183350 -0.281499
# Si   -0.532124 -0.164674 -0.210539  0.142701  1.000000 -0.034263 -0.192171
# K    -0.344942 -0.493401  0.326625  0.183350 -0.034263  1.000000 -0.499029
# Ca    0.760449 -0.102396 -0.371040 -0.281499 -0.192171 -0.499029  1.000000
# Ba   -0.070237  0.379839 -0.492262  0.479850 -0.020404 -0.076090 -0.140504
# Fe    0.094617 -0.251377  0.101841 -0.089357 -0.064187  0.078367  0.103456
# Type -0.168685  0.523700 -0.744993  0.605367  0.180933 -0.244500  0.045226
#
#             Ba        Fe      Type
# RI   -0.070237  0.094617 -0.168685
# Na    0.379839 -0.251377  0.523700
# Mg   -0.492262  0.101841 -0.744993
# ...

# %%
sns.heatmap(df_glass.corr(),annot=True)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
x = df_glass.iloc[:,:-1]

# %%
y = df_glass['Type']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
Num_col = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']

# %%
pipeline = Pipeline(
    steps = [('scaler',StandardScaler())]
)

# %%
preprocessor = ColumnTransformer([
    ('Num_pipe',pipeline,Num_col)
])

# %%
x_train = preprocessor.fit_transform(x_train)

# %%
x_test = preprocessor.transform(x_test)

# %% [markdown]
# # Model Building

# %% [markdown]
# # Bagging with Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
Model = RandomForestClassifier()

# %%
Model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = Model.predict(x_test)

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[18  1  0  0  0  0]
#  [ 4 18  0  0  1  0]
#  [ 2  0  2  0  0  0]
#  [ 0  3  0  3  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0 10]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.95      0.84        19
#            2       0.82      0.78      0.80        23
#            3       1.00      0.50      0.67         4
#            5       1.00      0.50      0.67         6
#            6       0.75      1.00      0.86         3
#            7       1.00      1.00      1.00        10
#
#     accuracy                           0.83        65
#    macro avg       0.89      0.79      0.80        65
# weighted avg       0.85      0.83      0.82        65

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {'n_estimators':[100,200,300],'criterion':['gini','entropy'],
             'max_depth':[3,5,10,15]}

# %%
RandomForest = RandomizedSearchCV(Model,param_distributions=parameters,cv=5,verbose=3)

# %%
RandomForest.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.633 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.700 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.733 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.733 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.586 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.700 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.700 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.700 total time=   0.0s
# ...

# %%
RandomForest.best_params_
# Out:
# {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy'}

# %%
Y = RandomForest.predict(x_test)

# %%
print(classification_report(y_test,Y))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.74      0.89      0.81        19
#            2       0.76      0.70      0.73        23
#            3       1.00      0.50      0.67         4
#            5       0.75      0.50      0.60         6
#            6       0.75      1.00      0.86         3
#            7       0.91      1.00      0.95        10
#
#     accuracy                           0.78        65
#    macro avg       0.82      0.77      0.77        65
# weighted avg       0.79      0.78      0.78        65

# %% [markdown]
# # Boosting with AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
adaboost_model = AdaBoostClassifier(n_estimators=100,random_state=42)
adaboost_model.fit(x_train,y_train)
adaboost_Y = adaboost_model.predict(x_test)
print(classification_report(y_test,adaboost_Y))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.51      0.95      0.67        19
#            2       0.38      0.35      0.36        23
#            3       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00         6
#            6       0.60      1.00      0.75         3
#            7       1.00      0.40      0.57        10
#
#     accuracy                           0.51        65
#    macro avg       0.42      0.45      0.39        65
# weighted avg       0.47      0.51      0.45        65

# %% [markdown]
# # Boosting with Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_model = GradientBoostingClassifier(n_estimators=100,random_state=42)
gradient_model.fit(x_train,y_train)
gradient_Y = gradient_model.predict(x_test)
print(classification_report(y_test,gradient_Y))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.72      0.95      0.82        19
#            2       0.76      0.70      0.73        23
#            3       1.00      0.50      0.67         4
#            5       0.50      0.33      0.40         6
#            6       0.67      0.67      0.67         3
#            7       0.90      0.90      0.90        10
#
#     accuracy                           0.75        65
#    macro avg       0.76      0.67      0.70        65
# weighted avg       0.76      0.75      0.74        65

# %% [markdown]
# # Additional Notes

# %% [markdown]
# 1. Explain Bagging and Boosting methods. How is it different from each other.
#
# answer:- Bagging and Boosting are both ensemble learning techniques used to improve the accuracy of machine learning models by combining multiple models, but the key difference lies in how these models are trained: Bagging trains models independently on different random subsets of data in parallel, while Boosting trains models sequentially, where each new model focuses on correcting the errors made by the previous model; essentially, Bagging aims to reduce variance by averaging predictions from diverse models, while Boosting aims to reduce bias by iteratively learning from mistakes made by earlier models

# %% [markdown]
# 2. Explain how to handle imbalance in the data.
#
# answer:- Handling imbalanced data is a critical aspect of machine learning, especially when working with classification tasks where one class significantly outnumbers others. In the context of the Glass dataset (or any classification problem), an imbalanced dataset can lead to biased models that perform well on the majority class but poorly on the minority class. Here are common techniques to handle imbalanced data:
# 1. Resampling Methods:
# 2. Adjusting Class Weights:
# 3. Use of Evaluation Metrics for Imbalanced Data:
# 4. Stratified Sampling:
# 5. SMOTE
