# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\VICTUS\Downloads\PCA\PCA\wine.csv")

# %%
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.isna().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %% [markdown]
# # Visaulizaton

# %% [markdown]
# # Histogram

# %%
sns.set_theme(style='darkgrid',palette='viridis')
df.hist(column=['Alcohol','Malic','Ash','Alcalinity','Magnesium','Phenols','Flavanoids',
                'Nonflavanoids','Proanthocyanins','Color','Hue','Dilution','Proline'],
                figsize=(30,18),bins=10)
plt.show()

# %% [markdown]
# # Density Plot

# %%
df.plot(kind='density', subplots=True,layout=(5,5),sharex=False, figsize=(20, 15))
plt.show()

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=(30,18))
plt.subplot(3,3,1)
plt.boxplot(df['Alcohol'])
plt.title('Alcohol')
plt.subplot(3,3,2)
plt.boxplot(df['Malic'])
plt.title('Malic')
plt.subplot(3,3,3)
plt.boxplot(df['Ash'])
plt.title('Ash')
plt.subplot(3,3,4)
plt.boxplot(df['Alcalinity'])
plt.title('Alcalinity')
plt.subplot(3,3,5)
plt.boxplot(df['Magnesium'])
plt.title('Magnesium')
plt.subplot(3,3,6)
plt.boxplot(df['Phenols'])
plt.title('Phenols')
plt.subplot(3,3,7)
plt.boxplot(df['Flavanoids'])
plt.title('Flavanoids')
plt.subplot(3,3,8)
plt.boxplot(df['Nonflavanoids'])
plt.title('Nonflavanoids')
plt.subplot(3,3,9)
plt.boxplot(df['Proanthocyanins'])
plt.title('Proanthocyanins')
plt.show()

# %%
plt.figure(figsize=(30,18))
plt.subplot(3,3,1)
plt.boxplot(df['Color'])
plt.title('Color')
plt.subplot(3,3,2)
plt.boxplot(df['Hue'])
plt.title('Hue')
plt.subplot(3,3,3)
plt.boxplot(df['Dilution'])
plt.title('Dilution')
plt.subplot(3,3,4)
plt.boxplot(df['Proline'])
plt.title('Proline')
# Out:
# Text(0.5, 1.0, 'Proline')

# %% [markdown]
# # Coorelation Metrics

# %%
df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# # Handling Outliers

# %%
def Outliers(data,columns):
    for col in columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        IQR = q3 - q1
        Low_ext = q1 - (1.5*IQR)
        Upp_ext = q3 + (1.5*IQR)
        df[col] = np.where(df[col]>Upp_ext,Upp_ext,np.where(df[col]<Low_ext,Low_ext,df[col]))

# %%
Outliers(df,df.iloc[:,2:6])

# %%
Outliers(df,df.iloc[:,9:12])

# %% [markdown]
# # Dimensionality Reduction with PCA

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(df.drop('Type',axis=1))
scaled_data
# Out:
# array([[ 1.51861254, -0.56553422,  0.24064008, ...,  0.36660959,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.50172839, -0.86217567, ...,  0.41076822,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02694849,  1.15331518, ...,  0.32245097,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.77705125, -0.40583812, ..., -1.6205284 ,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.23659622,  0.0124713 , ..., -1.57636978,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.61297912,  1.41951209, ..., -1.53221115,
#         -1.42894777, -0.59516041]])

# %%
# Implementaion of PCA
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca_data = pca.fit_transform(scaled_data)

# %%
# Scree Plot
plt.plot(range(1,len(pca.explained_variance_ratio_)+1),pca.explained_variance_ratio_,marker='o')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
# Cumulative Explained Variance
cumulative_variance = pca.explained_variance_ratio_.cumsum()

# %%
plt.plot(range(1,len(cumulative_variance)+1),cumulative_variance,marker='o')
plt.title('Cumulative Explained Variance')
plt.xlabel('No. of Principal Component')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
# Transform original data into Principal components
pca1 = PCA(n_components=4)
optimal_pca_data = pca1.fit_transform(scaled_data)
pca_df = pd.DataFrame(optimal_pca_data, columns=[f'PC{i+1}' for i in range(4)])

# %% [markdown]
# # Clustering with Original Data

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3,random_state=42)

# %%
kmeans.fit(scaled_data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df['Cluster'] = kmeans.labels_

# %%
# Visualize Clustering result
df['PC1'] = pca_df.PC1

# %%
df['PC2'] = pca_df.PC2

# %%
sns.scatterplot(x=df['PC1'],y=df['PC2'],hue=df['Cluster'],data=df)
plt.show()

# %%
# Evaluate Clustering Performnce
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score

# %%
print('Silhouette_score_Original:-',silhouette_score(scaled_data,kmeans.labels_))
# Out:
# Silhouette_score_Original:- 0.2854626783251893

# %%
print('Davies_Bouldin_Score_Original:-',davies_bouldin_score(scaled_data,kmeans.labels_))
# Out:
# Davies_Bouldin_Score_Original:- 1.3816062413276704

# %% [markdown]
# # Clustering with PCA Data

# %%
# Apply the same clustering algorithm to the PCA-transformed dataset
pca = PCA(n_components=4)
pca_transformed_data = pca.fit_transform(scaled_data)

# %%
kmeans_pca = KMeans(n_clusters=3,random_state=42)
kmeans_pca.fit(pca_transformed_data)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
pca_cluster_labels = kmeans_pca.labels_

# %%
# If the PCA transformation is more than 2 dimensions, reduce it for visualization
pca_2d_for_visualization = PCA(n_components=2)
pca_2d_visual = pca_2d_for_visualization.fit_transform(pca_transformed_data)

# %%
# Create a scatter plot of the 2D PCA components
sns.scatterplot(x=pca_2d_visual[:, 0], y=pca_2d_visual[:, 1], hue=pca_cluster_labels)
plt.title('Clustering on PCA-Transformed Data (2D Visualization)')
plt.show()

# %%
# Calculate silhouette score for PCA-transformed data
print('Silhouette_Score_Tranformed_data:-',silhouette_score(pca_transformed_data, pca_cluster_labels))
# Out:
# Silhouette_Score_Tranformed_data:- 0.4065922394524315

# %%
# Comparing Silhouette Score
print('Silhouette Score (Original):-',silhouette_avg)
print('Silhouette Score (PCA):-',silhouette_score(pca_transformed_data,pca_cluster_labels))
# Out:
# Silhouette Score (Original):- 0.2854626783251893
# Silhouette Score (PCA):- 0.4065922394524315

# %%
# Calculate Davies-Bouldin index for PCA-transformed data
print('Davies-Bouldin_Score_Transformed_data:-',davies_bouldin_score(pca_transformed_data, pca_cluster_labels))
# Out:
# Davies-Bouldin_Score_Transformed_data:- 0.9857540570348063

# %%
# Comparing Davies-Bouldin Score
print('Davies_Bouldin_Score (Original):-',davies_bouldin_score(scaled_data,kmeans.labels_))
print('Davies-Bouldin_Score (PCA):-',davies_bouldin_score(pca_transformed_data, pca_cluster_labels))
# Out:
# Davies_Bouldin_Score (Original):- 1.3816062413276704
# Davies-Bouldin_Score (PCA):- 0.9857540570348063

# %% [markdown]
# # Comparing Clustering results from original data and PCA Transformed data

# %%
print('Silhouette Score (Original):-',silhouette_avg)
print('Davies_Bouldin_Score (Original):-',davies_bouldin_score(scaled_data,kmeans.labels_))
# Out:
# Silhouette Score (Original):- 0.2854626783251893
# Davies_Bouldin_Score (Original):- 1.3816062413276704

# %%
print('Silhouette Score (PCA):-',silhouette_score(pca_transformed_data,pca_cluster_labels))
print('Davies-Bouldin_Score_Transformed_data:-',davies_bouldin_score(pca_transformed_data, pca_cluster_labels))
# Out:
# Silhouette Score (PCA):- 0.4065922394524315
# Davies-Bouldin_Score_Transformed_data:- 0.9857540570348063

# %% [markdown]
# # Compare Cluster

# %%
# Compare cluster memberships from original and PCA-transformed data
original_clusters = kmeans.labels_
pca_clusters = kmeans_pca.labels_

# %%
comparison_df = pd.DataFrame({'Original_Clusters': original_clusters, 'PCA_Clusters': pca_clusters})

# %%
print(comparison_df.head())
# Out:
#    Original_Clusters  PCA_Clusters
# 0                  2             2
# 1                  2             2
# 2                  2             2
# 3                  2             2
# 4                  2             2

# %%
comparison_table = pd.crosstab(comparison_df['Original_Clusters'], comparison_df['PCA_Clusters'])
print(comparison_table)
# Out:
# PCA_Clusters        0   1   2
# Original_Clusters
# 0                  64   0   1
# 1                   0  51   0
# 2                   0   0  62
